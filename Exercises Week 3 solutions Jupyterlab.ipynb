# %%
import pandas as pd
insurance = pd.read_csv('insurance.csv')

# %%
#q1a: check for multicollinearity
print(insurance.corr())
#no high collinearity found

# %%
#q1b: recode the variable
import numpy as np
insurance['east_west'] = np.where((insurance['region']=='southwest') | (insurance['region']=='northwest'), 1, 0)
#recode the categorical variables while we're at it
dummies = pd.get_dummies(insurance[['sex','smoker']])
insurance = pd.concat([insurance,dummies],axis=1)
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  east_west  \
# 0   19  female  27.900         0    yes  southwest  16884.92400          1
# 1   18    male  33.770         1     no  southeast   1725.55230          0
# 2   28    male  33.000         3     no  southeast   4449.46200          0
# 3   33    male  22.705         0     no  northwest  21984.47061          1
# 4   32    male  28.880         0     no  northwest   3866.85520          1
#
#    sex_female  sex_male  smoker_no  smoker_yes
# 0           1         0          0           1
# 1           0         1          1           0
# 2           0         1          1           0
# 3           0         1          1           0
# 4           0         1          1           0

# %%
#q1c
import statsmodels.formula.api as sm
model1a = sm.ols('charges~east_west', data = insurance).fit()
print(model1a.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     6.829
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):            0.00907
# Time:                        10:46:04   Log-Likelihood:                -14474.
# No. Observations:                1338   AIC:                         2.895e+04
# Df Residuals:                    1336   BIC:                         2.896e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.411e+04    460.687     30.627      0.000    1.32e+04     1.5e+04
# east_west  -1727.2761    660.963     -2.613      0.009   -3023.914    -430.638
# ==============================================================================
# Omnibus:                      332.714   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              640.370
# Skew:                           1.500   Prob(JB):                    8.82e-140
# Kurtosis:                       4.577   Cond. No.                         2.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#q1d: 
model1b = sm.ols('charges~east_west+age',data=insurance).fit()
print(model1b.summary()) #east_west stays significant
model1c = sm.ols('charges~east_west+sex_female',data=insurance).fit()
print(model1c.summary()) #east_west stays significant
model1d = sm.ols('charges~east_west+bmi',data=insurance).fit()
print(model1d.summary()) #east_west is no longer significant
model1e = sm.ols('charges~east_west+children',data=insurance).fit()
print(model1e.summary()) #east_west stays significant
model1f = sm.ols('charges~east_west+smoker_yes',data=insurance).fit()
print(model1f.summary()) #east_west is no longer significant
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     69.95
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):           1.29e-29
# Time:                        11:12:09   Log-Likelihood:                -14411.
# No. Observations:                1338   AIC:                         2.883e+04
# Df Residuals:                    1335   BIC:                         2.884e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4013.5035    981.395      4.090      0.000    2088.259    5938.748
# east_west  -1787.1060    630.699     -2.834      0.005   -3024.374    -549.838
# age          258.2469     22.444     11.506      0.000     214.217     302.277
# ==============================================================================
# Omnibus:                      396.151   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              851.563
# Skew:                           1.721   Prob(JB):                    1.22e-185
# Kurtosis:                       4.852   Cond. No.                         134.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     5.561
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):            0.00394
# Time:                        11:12:09   Log-Likelihood:                -14472.
# No. Observations:                1338   AIC:                         2.895e+04
# Df Residuals:                    1335   BIC:                         2.897e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.478e+04    561.784     26.302      0.000    1.37e+04    1.59e+04
# east_west  -1709.3082    660.211     -2.589      0.010   -3004.473    -414.144
# sex_female -1364.6826    659.981     -2.068      0.039   -2659.395     -69.970
# ==============================================================================
# Omnibus:                      327.475   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              624.482
# Skew:                           1.482   Prob(JB):                    2.49e-136
# Kurtosis:                       4.555   Cond. No.                         3.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     28.97
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):           4.84e-13
# Time:                        11:12:09   Log-Likelihood:                -14449.
# No. Observations:                1338   AIC:                         2.890e+04
# Df Residuals:                    1335   BIC:                         2.892e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2111.0072   1742.318      1.212      0.226   -1306.973    5528.987
# east_west  -1158.3862    653.851     -1.772      0.077   -2441.074     124.301
# bmi          382.2851     53.609      7.131      0.000     277.119     487.452
# ==============================================================================
# Omnibus:                      260.518   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              430.233
# Skew:                           1.292   Prob(JB):                     3.77e-94
# Kurtosis:                       4.019   Cond. No.                         169.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     6.820
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):            0.00113
# Time:                        11:12:09   Log-Likelihood:                -14471.
# No. Observations:                1338   AIC:                         2.895e+04
# Df Residuals:                    1335   BIC:                         2.896e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.336e+04    541.875     24.660      0.000    1.23e+04    1.44e+04
# east_west  -1796.1832    660.068     -2.721      0.007   -3091.066    -501.300
# children     712.9527    273.767      2.604      0.009     175.892    1250.013
# ==============================================================================
# Omnibus:                      336.689   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              652.772
# Skew:                           1.513   Prob(JB):                    1.79e-142
# Kurtosis:                       4.597   Cond. No.                         4.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.620
# Model:                            OLS   Adj. R-squared:                  0.620
# Method:                 Least Squares   F-statistic:                     1090.
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):          2.16e-281
# Time:                        11:12:09   Log-Likelihood:                -13830.
# No. Observations:                1338   AIC:                         2.767e+04
# Df Residuals:                    1335   BIC:                         2.768e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8695.4846    307.618     28.267      0.000    8092.018    9298.952
# east_west   -520.4759    409.340     -1.271      0.204   -1323.497     282.545
# smoker_yes  2.358e+04    506.978     46.501      0.000    2.26e+04    2.46e+04
# ==============================================================================
# Omnibus:                      135.418   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              211.707
# Skew:                           0.724   Prob(JB):                     1.07e-46
# Kurtosis:                       4.304   Cond. No.                         3.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#q1d(continued)
#table showing averages split up by east_west show that the bmi in the west is lower and that fewer people smoke in the west
print(insurance.groupby('east_west').mean())
# Out:
# smoker_yes        0         1
# east_west
# 0           0.49812  0.576642
# 1           0.50188  0.423358
#                  age       bmi  children       charges  sex_female  sex_male  \
# east_west
# 0          39.094477  31.38633  1.047965  14109.532481    0.488372  0.511628
# 1          39.326154  29.89820  1.144615  12382.256376    0.501538  0.498462
#
#            smoker_no  smoker_yes
# east_west
# 0           0.770349    0.229651
# 1           0.821538    0.178462

# %%
#q2
#first import the file
cpu = pd.read_csv('cpu.csv')
cpu.head()
# Out:
#    CpuTime  CardsIn  LinesOut  Steps  MountedDevices
# 0   0.4190      297     11714     15               0
# 1   0.4678      387     13901     15               0
# 2   0.0543      349       791      3               3
# 3   0.0590      468       965      3               3
# 4   0.0360       12       254      3               3

# %%
#q2a
model2a = sm.ols('CpuTime ~ CardsIn + LinesOut + Steps + MountedDevices', data=cpu).fit()
print(model2a.summary())
#the R-squared is very high (>0.9) so we can use it for predictions
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CpuTime   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     123.1
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):           2.41e-19
# Time:                        11:47:38   Log-Likelihood:                 76.330
# No. Observations:                  38   AIC:                            -142.7
# Df Residuals:                      33   BIC:                            -134.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.0027      0.011      0.247      0.806      -0.020       0.025
# CardsIn        -2.884e-05   4.03e-05     -0.716      0.479      -0.000    5.31e-05
# LinesOut        2.165e-05   2.84e-06      7.627      0.000    1.59e-05    2.74e-05
# Steps              0.0092      0.002      4.345      0.000       0.005       0.013
# MountedDevices     0.0124      0.003      4.242      0.000       0.006       0.018
# ==============================================================================
# Omnibus:                        2.142   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.101
# Skew:                           0.296   Prob(JB):                        0.577
# Kurtosis:                       3.587   Cond. No.                     9.84e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.84e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#q2b: CardsIn is not significant so we will take it out
model2b = sm.ols('CpuTime ~ LinesOut + Steps + MountedDevices', data=cpu).fit()
print(model2b.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CpuTime   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     166.4
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):           2.20e-20
# Time:                        11:48:59   Log-Likelihood:                 76.037
# No. Observations:                  38   AIC:                            -144.1
# Df Residuals:                      34   BIC:                            -137.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.0015      0.011      0.137      0.892      -0.020       0.023
# LinesOut        2.109e-05   2.71e-06      7.786      0.000    1.56e-05    2.66e-05
# Steps              0.0092      0.002      4.408      0.000       0.005       0.014
# MountedDevices     0.0122      0.003      4.225      0.000       0.006       0.018
# ==============================================================================
# Omnibus:                        2.125   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.346   Jarque-Bera (JB):                1.128
# Skew:                           0.353   Prob(JB):                        0.569
# Kurtosis:                       3.462   Cond. No.                     9.72e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.72e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#q2c: predict the first row
cpupred = model2b.predict() #create the predictions
print(cpupred) #print all the predictions
print(cpupred[0]) #print just the first prediction

#compare the prediction with the real value:
print("the prediction is off by", cpu.CpuTime[0] - cpupred[0])
# Out:
# [0.38714425 0.43326979 0.08242194 0.08609173 0.07109619 0.09549822
#  0.03774196 0.02542132 0.03729906 0.02504169 0.03860668 0.02590641
#  0.1627082  0.05164079 0.13691418 0.05140879 0.15526315 0.04412134
#  0.258988   0.06310304 0.47181507 0.040325   0.24264265 0.18040414
#  0.02609623 0.20167089 0.1802776  0.18034087 0.244583   0.07449206
#  0.29927139 0.05831544 0.26419742 0.09235596 0.4115798  0.24112411
#  0.31030187 0.18031978]
# 0.3871442539738491
# the prediction is off by 0.03185574602615088
